# %% [markdown]
# ### 3.Capitalize ()

# %%
a="jai shree krishna"
print(a)
b=a.capitalize()
print(b)
# Out:
# jai shree krishna
# Jai shree krishna

# %% [markdown]
# ### 4.Title ()

# %%
a="jai shree krishna"
print(a)
b=a.title()
print(b)
# Out:
# jai shree krishna
# Jai Shree Krishna

# %% [markdown]
# ### 5.Swapcase ()

# %%
a="JAI SHREE KRISHNA"
print(a)
b=a.swapcase()
print(b)
# Out:
# JAI SHREE KRISHNA
# jai shree krishna

# %% [markdown]
# ### BUILT IN FUNCTION - Conversion Method

# %% [markdown]
# ### 1.STR ()

# %%
a=20
b=20.5
c=20+1j
print(type(a))
print(type(b))
print(type(c))

new_a=str(a)
new_b=str(b)
new_c=str(c)

print(new_a)
print(new_b)
print(new_c)

print(type(new_a))
print(type(new_b))
print(type(new_c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# 20
# 20.5
# (20+1j)
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ### 2. INT ()

# %%
d="10"
print(type(d))
new_d=int(d)
print(type(new_d))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### 3. FLOAT ()

# %%
e="10.1"
print(type(e))
new_e=(float(e))
print(type(new_e))
# Out:
# <class 'str'>
# <class 'float'>

# %% [markdown]
# ### 4. COMPLEX ()

# %%
f="10+1j"
print(type(f))
new_f=complex(f)
print(type(new_f))
print(new_f)
# Out:
# <class 'str'>
# <class 'complex'>
# (10+1j)

# %% [markdown]
# ## JOIN METHOD

# %% [markdown]
# ### 1. SPLIT ()

# %%
str1="jai shree krishna"
print(str1.split())
# Out:
# ['jai', 'shree', 'krishna']

# %% [markdown]
# ### JOIN ()

# %%
words=("jai","shree","krishna")
print(" ".join(words))
# Out:
# jai shree krishna

# %%
a=("Hello world")
print(a[0])
# Out:
# H
