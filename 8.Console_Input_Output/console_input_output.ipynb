# %% [markdown]
# ### CONSOLE INPUT / OUTPUT -

# %% [markdown]
# #### Console input allows programmes to interact with users

# %% [markdown]
# ### Console Output Function ( )

# %% [markdown]
# #### Output - print ( )

# %% [markdown]
# ##### The Print ( ) Function Displays O/P To The Screen / Console.

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
print("Hello World")
print("good morning")
print(type("Hello World"))
# Out:
# Hello World
# good morning
# <class 'str'>

# %%
print(10.1)
print(type(10.1))
# Out:
# 10.1
# <class 'float'>

# %%
print(type(True))
print(type(10+1j))
# Out:
# <class 'bool'>
# <class 'complex'>

# %%
name="vaishnavi"
add="pune"
pin_code=411033
wt=50.5
print(name,pin_code,add,wt)
print(type(name),type(pin_code),type(add),type(wt))
# Out:
# vaishnavi 411033 pune 50.5
# <class 'str'> <class 'int'> <class 'str'> <class 'float'>

# %%
name="vaishnavi"
add="kopargaon"
print("my name is",name,)
print("my add is ",add)
print("my name is:\n",name,"\nand my address is:\n",add)
# Out:
# my name is vaishnavi
# my add is  kopargaon
# my name is:
#  vaishnavi
# and my address is:
#  kopargaon
