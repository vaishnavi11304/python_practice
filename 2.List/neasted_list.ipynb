# %% [markdown]
# ### NEASTED LIST ( ) list of list

# %%
l1=[10,20,30]
l2=[40,50,6]
l3=[l1,l2]
print(l3)
print(l3[0])
# Out:
# [[10, 20, 30], [40, 50, 6]]
# [10, 20, 30]

# %% [markdown]
# #### in the is l3 there is one list but inside l3 l1 is consider 0 and l2 is consider 1 as per / for indexing number

# %% [markdown]
# #### here we are accesing inside the 1st list numbers

# %%
l1=[10,20,30,5]
l2=[40,50,6]
l3=[l1,l2]
print(l3)
print(l3[0])

print(l3[0][1])
print(l3[0][2])
print(l3[1][1])
print(l3[1][2])
print(l3[0][3])
# Out:
# [[10, 20, 30, 5], [40, 50, 6]]
# [10, 20, 30, 5]
# 20
# 30
# 50
# 6
# 5
