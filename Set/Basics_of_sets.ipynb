# %% [markdown]
# ### SETS { }

# %% [markdown]
# #### Sets is defined using { } braces and element seprated by comma's and encloed in  { } braces

# %% [markdown]
# #### 1. HOMOGENEOUS ELEMENT { }

# %% [markdown]
# ##### Here , we add only 1 data Types Element

# %%
a = { 10,20,30,40,50,60}
print(a)
print(type(a))
print(id(a))
# Out:
# {50, 20, 40, 10, 60, 30}
# <class 'set'>
# 2424109263200

# %% [markdown]
# ### 2. HETROGENEOUS ELEMENT { }

# %% [markdown]
# ##### here, we add multiple data Types

# %%
a={1,1.2,2+5j,"vishu",True,False}
print(a)
print(type(a))
# Out:
# {False, 1, 1.2, (2+5j), 'vishu'}
# <class 'set'>

# %%
b={25,25.6,96,2+6j,"heyy"}
print(b)
# Out:
# {96, (2+6j), 'heyy', 25, 25.6}

# %% [markdown]
# #### In Set's Duplicate Element Are Not Allowed - But if We Take Duplicate Element Than Its not Give Any Error Its take Single value From The Set's

# %%
a1={1,2,3,5,4,1,2,3,4,5,12.5,56,89,"vishu","vishu"}
print(a1)
# Out:
# {1, 2, 3, 4, 5, 12.5, 'vishu', 56, 89}

# %%
a=0
b=1
while (b<50):
    print(b)
    a,b=b,a+b
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21
# 34

# %%
def find_largest(num_list):
    largest=num_list[0]
