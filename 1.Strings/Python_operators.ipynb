# %% [markdown]
# ## ARTHIMATIC OPERATOR

# %% [markdown]
# ### 1.Addition (+)

# %%
p=12
q=56
result=p+q
print(result)
print(p+q)
# Out:
# 68
# 68

# %% [markdown]
# ### 2.Substraction (-)

# %%
p=96
q=78
result1=p-q
print(result1)
# Out:
# 18

# %% [markdown]
# ### 3.Multiplication (*)

# %%
a=12
b=4
print(a*b)
# Out:
# 48

# %% [markdown]
# ### 4.Division (/)

# %%
c=12
d=4
print(c/d)
# Out:
# 3.0

# %% [markdown]
# ### 5.Floor Division (//)

# %%
c1=12
d1=4
print(c1//d1)
# Out:
# 3

# %% [markdown]
# ### 6.Modulus (%)

# %% [markdown]
# #### Modulus gives the reminder of Available value

# %%
p=13
q=3
print(p%q)
# Out:
# 1

# %%
a=29
b=4
print(a%b)
# Out:
# 1

# %%
c=30
d=5
print(c%d)
# Out:
# 0

# %% [markdown]
# ### 7.Exponential (**)

# %%
v=2
s=4
print(v**s)
# Out:
# 16

# %% [markdown]
# ### PRECENDANCE (Order Of Operation)

# %% [markdown]
# #### 1.Paranthesis () - Highest Precendance

# %%
value=(9+3)*2
print(value)

value2=(9+1+2+3+6)-10
print(value2)
# Out:
# 24
# 11

# %% [markdown]
# ### 2.Exponentation - (**)

# %%
v1=4+2**3
print(v1)
# Out:
# 12

# %% [markdown]
# ### 3.MULTLIPICATION,DIVISON,FLOOR DIVISON , MODULUS - (* , / , // , %)

# %%
V4=18-3*4
print(V4)
# Out:
# 6

# %% [markdown]
# ### 4.Addition & substraction (+ , -)

# %%
value5=20-5+3
print(value5)
# Out:
# 18
