# %% [markdown]
# ## String Method

# %%
a="hello world"
print(id(a))
# Out:
# 1660458167344

# %% [markdown]
# ### 1.Isalpha ()

# %% [markdown]
# #### This method check all element are alphabeticals or not if anyone is int or float it will return false if we gave a space too its also false

# %%
a1="helloworld2"
print(a1.isalpha())
# Out:
# False

# %%
intro="hiimynameisvaishnavi"
print(intro.isalpha())
# Out:
# True

# %%
intro="hii myname is vaishnavi"
print(intro.isalpha())
# Out:
# False

# %% [markdown]
# ### 2.Is digit()

# %% [markdown]
# #### This method chcek all are digit/int or not if space and alphabetics are in it's return false

# %%
a2="1231"
print(a2.isdigit())
# Out:
# True

# %%
a2="123156987456359956163"
print(a2.isdigit())
# Out:
# True

# %%
a5="1231 "
print(a5.isdigit())
# Out:
# False

# %%
a2="1231 as we discussed its return false"
print(a2.isdigit())
# Out:
# False

# %%
a2="1,2,3,5,,7,8"
print(a2.isdigit())
# Out:
# False

# %% [markdown]
# ### 3.isalnum ()

# %% [markdown]
# ####  Its check all element are alphabets and number are not here spaces are also consider as false statement

# %%
a3="hello1234"
print(a3.isalnum())
# Out:
# True

# %%
a5="hello1234 $$$"
print(a5.isalnum())
# Out:
# False

# %%
a6="hello 1234"
print(a6.isalnum())
# Out:
# False

# %% [markdown]
# ### 4.Is lower ()

# %% [markdown]
# #### this method check in every elements all character is in small letter or not if anyone is capital its return false

# %%
str11="hello worlD"
print(str11.islower())
# Out:
# False

# %%
str11="hello world"
print(str11.islower())
# Out:
# True

# %%
str12="hello world we learn# $something new here"
print(str11.islower())
# Out:
# True

# %% [markdown]
# ### 5.is upper ()

# %% [markdown]
# #### this method check in every elements all character is in capital  letter or not if anyone is small its return false

# %%
str11="HELLO WORLD"
print(str11.isupper())
# Out:
# True

# %%
str12="hello world we learn# $something new here"
print(str11.isupper())
# Out:
# False

# %%
str13="hello HJHSJKDHSK kjskdjjckn"
print(str13.isupper())
# Out:
# False

# %% [markdown]
# ### 6.startswith ()

# %% [markdown]
# #### This method check exact element are endswith the same or not if even single charcter is not match like 'A' or 'a' its print false

# %%
str12="hello world 11"
print(str12.startswith("hello"))
# Out:
# True

# %%
str12="hello world 11"
print(str12.startswith("Hello"))
# Out:
# False

# %%
str12="hey ,hello world 11"
print(str12.startswith("hey"))
# Out:
# True

# %% [markdown]
# ### 7.Endswith ()

# %% [markdown]
# #### This method check exact element are endswith the same or not if even single charcter is not match like 'A' or 'a' its print false

# %%
str13="hello world 11"
print(str13.endswith("11"))
# Out:
# True

# %%
str13="hello world vaishnavi"
print(str13.endswith("vaishnavi"))
# Out:
# True

# %%
str13="hello world vaishnavi"
print(str13.endswith("Vaishnavi"))
# Out:
# False

# %% [markdown]
# ## 2 - Searching Method

# %% [markdown]
# ### 1.FIND ()

# %% [markdown]
# #### find method check particular element is in which indexing number after checking its return which indexing number exactly is that

# %% [markdown]
# #### If there is too many same number it will consider only 1st element

# %%
text="hello world "
print(text.find("world"))
# Out:
# 6

# %%
str12="hello world 11"
print(str12.find("hello"))
# Out:
# 0

# %%
str13="hello world vaishnavi"
print(str13.find("vaishnavi"))
# Out:
# 12

# %%
str13="hello world vaishnavi"
print(str13.find(" "))
# Out:
# 5
